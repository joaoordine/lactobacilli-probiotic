# %%
library(dplyr)

# Corrected list of isolates
isolates <- c(
  "Lactobacillus plantarum", "Lactobacillus sp.", "Lactobacillus fermentum",
  "Lactobacillus sp.", "Lactobacillus plantarum", "Lactobacillus plantarum",
  "Lactobacillus sp.", "Lactobacillus plantarum", "Lactobacillus plantarum",
  "Lactobacillus plantarum", "Lactobacillus plantarum", "Lactobacillus fermentum",
  "Lactobacillus fermentum", "Lactobacillus plantarum", "Lactobacillus plantarum",
  "Lactobacillus sp.", "Lactobacillus plantarum", "Lactobacillus plantarum",
  "Lactobacillus plantarum", "Lactobacillus plantarum", "Lactobacillus plantarum",
  "Lactobacillus sp.", "Lactobacillus fermentum", "Lactobacillus plantarum",
  "Lactobacillus plantarum", "Lactobacillus sp.", "Lactobacillus plantarum",
  "Lactobacillus fermentum", "Lactobacillus fermentum", "Lactobacillus fermentum",
  "Lactobacillus fermentum"
)

# Summarize counts
summary_table <- data.frame(isolate = isolates) %>%
  group_by(isolate) %>%
  summarise(count = n(), .groups = "drop") %>%
  arrange(desc(count))

summary_table
# Out:
#   isolate                 count
# 1 Lactobacillus plantarum 17
# 2 Lactobacillus fermentum  8
# 3 Lactobacillus sp.        6
